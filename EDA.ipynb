# %%
import pandas as pd
from os import listdir
from statistics import mean

# %%
listdir('data')
# Out:
# ['OV-US',
#  'organize_data.py',
#  'COAD-US',
#  '.DS_Store',
#  'list_data_dirs.py',
#  'UCEC-US',
#  'PRAD-US',
#  'KIRC-US',
#  'SKCM-US',
#  'THCA-US',
#  'LGG-US',
#  'GBM-US',
#  'LUSC-US',
#  'BLCA-US',
#  'BRCA-US',
#  '.remove_duplicates.py.swo']

# %%
def look(cancer_code):
    DATA_PATH = 'data/'
    PATH = DATA_PATH + cancer_code + '/'
    
    feat = []
    ids = []
    donors = []
    
    all_files = [file for file in listdir(PATH)]
    
    for file in all_files:
        df = pd.read_csv(PATH + file, sep='\t')
        feat.append(len(df.columns))
        ids.append(len(set(df['icgc_mutation_id'])))
        donors.append(len(set(df['icgc_donor_id'])))
    
    print('*' * 40)
    print('Project code: ', cancer_code)
    
    try:
        print('Average number of features: {}'.format(mean(feat)))
        print('Average number of mutations: {}'.format(mean(ids)))
        print('Number of donors: {}'.format(sum(donors)))
    except:
        print(NULL)

# %%
folders = [file for file in listdir('data') if 'US' in file]
for cancer in folders:
    look(cancer)
# Out:
# ****************************************
# Project code:  OV-US
# Average number of features: 42
# Average number of mutations: 105.53217821782178
# Number of donors: 404
# ****************************************
# Project code:  COAD-US
# Average number of features: 42
# Average number of mutations: 1949.2
# Number of donors: 280
# ****************************************
# Project code:  UCEC-US
# Average number of features: 42
# Average number of mutations: 3093.343108504399
# Number of donors: 341
# ****************************************
# Project code:  PRAD-US
# Average number of features: 42
# Average number of mutations: 25.90277777777778
# Number of donors: 144
# ****************************************
# Project code:  KIRC-US
# Average number of features: 42
# Average number of mutations: 106.89270386266094
# Number of donors: 233
# ****************************************
# Project code:  SKCM-US
# Average number of features: 42
# Average number of mutations: 1890.2366666666667
# Number of donors: 300
# ****************************************
# Project code:  THCA-US
# Average number of features: 42
# Average number of mutations: 41.88135593220339
# Number of donors: 295
# ****************************************
# Project code:  LGG-US
# Average number of features: 42
# Average number of mutations: 175.17207792207793
# Number of donors: 308
# ****************************************
# Project code:  GBM-US
# Average number of features: 42
# Average number of mutations: 188.38186813186815
# Number of donors: 364
# ****************************************
# Project code:  LUSC-US
# Average number of features: 42
# Average number of mutations: 9.411157024793388
# Number of donors: 484
# ****************************************
# Project code:  BLCA-US
# Average number of features: 42
# Average number of mutations: 55.48048780487805
# Number of donors: 410
# ****************************************
# Project code:  BRCA-US
# Average number of features: 42
# Average number of mutations: 130.88801571709234
# Number of donors: 1018

# %% [markdown]
# ### Reading in each file
# Each file represents one individual. We could probably use the project_code feature as our target/output.

# %%
df = pd.read_csv('data/BRCA-US/simple_somatic_mutation.open-2020-03-02T154602.752.tsv', sep='\t')

# %%
print('Number of features: {}'.format(len(df.columns)))
print(df.columns)
# Out:
# Number of features: 42
# Index(['icgc_mutation_id', 'icgc_donor_id', 'project_code', 'icgc_specimen_id',
#        'icgc_sample_id', 'matched_icgc_sample_id', 'submitted_sample_id',
#        'submitted_matched_sample_id', 'chromosome', 'chromosome_start',
#        'chromosome_end', 'chromosome_strand', 'assembly_version',
#        'mutation_type', 'reference_genome_allele', 'mutated_from_allele',
#        'mutated_to_allele', 'quality_score', 'probability', 'total_read_count',
#        'mutant_allele_read_count', 'verification_status',
#        'verification_platform', 'biological_validation_status',
#        'biological_validation_platform', 'consequence_type', 'aa_mutation',
#        'cds_mutation', 'gene_affected', 'transcript_affected',
#        'gene_build_version', 'platform', 'experimental_protocol',
#        'sequencing_strategy', 'base_calling_algorithm', 'alignment_algorithm',
#        'variation_calling_algorithm', 'other_analysis_algorithm',
#        'seq_coverage', 'raw_data_repository', 'raw_data_accession',
#        'initial_data_release_date'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   icgc_mutation_id icgc_donor_id project_code icgc_specimen_id icgc_sample_id  \
# 0          MU22195        DO5200      BRCA-US          SP10944        SA60252
# 1          MU22195        DO5200      BRCA-US          SP10944        SA60252
# 2          MU22195        DO5200      BRCA-US          SP10944        SA60228
# 3          MU22195        DO5200      BRCA-US          SP10944        SA60228
# 4          MU23549        DO5200      BRCA-US          SP10944        SA60228
#
#   matched_icgc_sample_id           submitted_sample_id  \
# 0                SA60348  TCGA-BH-A18U-01A-21D-A19H-09
# 1                SA60348  TCGA-BH-A18U-01A-21D-A19H-09
# 2                SA60324  TCGA-BH-A18U-01A-21D-A12B-09
# 3                SA60324  TCGA-BH-A18U-01A-21D-A12B-09
# 4                SA60324  TCGA-BH-A18U-01A-21D-A12B-09
#
#     submitted_matched_sample_id chromosome  chromosome_start  ...  \
# 0  TCGA-BH-A18U-11A-23D-A19H-09          5          58021869  ...
# 1  TCGA-BH-A18U-11A-23D-A19H-09          5          58021869  ...
# 2  TCGA-BH-A18U-11A-23D-A12B-09          5          58021869  ...
# 3  TCGA-BH-A18U-11A-23D-A12B-09          5          58021869  ...
# 4  TCGA-BH-A18U-11A-23D-A12B-09          7          70886058  ...
#
#    experimental_protocol  sequencing_strategy base_calling_algorithm  \
# 0                    NaN                  WGS                    NaN
# 1                    NaN                  WGS                    NaN
# 2                    NaN                  WXS                    NaN
# 3                    NaN                  WXS                    NaN
# 4                    NaN                  WXS                    NaN
#
#   alignment_algorithm                        variation_calling_algorithm  \
# 0                 NaN                     PCAWG Consensus SNV-MNV caller
# 1                 NaN                     PCAWG Consensus SNV-MNV caller
# 2                 NaN  TCGA-MC3 https://gdc.cancer.gov/about-data/pub...
# 3                 NaN  TCGA-MC3 https://gdc.cancer.gov/about-data/pub...
# 4                 NaN  TCGA-MC3 https://gdc.cancer.gov/about-data/pub...
#
#   other_analysis_algorithm seq_coverage  raw_data_repository  \
# 0                      NaN          NaN                  NaN
# 1                      NaN          NaN                  NaN
# 2                      NaN          NaN                  GDC
# 3                      NaN          NaN                  GDC
# 4                      NaN          NaN                  GDC
#
#              raw_data_accession  initial_data_release_date
# 0               FI30202:FI30201                        NaN
# 1               FI30202:FI30201                        NaN
# 2  TCGA-BH-A18U-01A-21D-A12B-09                        NaN
# 3  TCGA-BH-A18U-01A-21D-A12B-09                        NaN
# 4  TCGA-BH-A18U-01A-21D-A12B-09                        NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# Notice how for one donor there are duplicate icgc_mutation_id values. Not sure what this means.

# %%
# Mutation ID MU22195
df[df['icgc_mutation_id'] == 'MU22195']
# Out:
#   icgc_mutation_id icgc_donor_id project_code icgc_specimen_id icgc_sample_id  \
# 0          MU22195        DO5200      BRCA-US          SP10944        SA60252
# 1          MU22195        DO5200      BRCA-US          SP10944        SA60252
# 2          MU22195        DO5200      BRCA-US          SP10944        SA60228
# 3          MU22195        DO5200      BRCA-US          SP10944        SA60228
#
#   matched_icgc_sample_id           submitted_sample_id  \
# 0                SA60348  TCGA-BH-A18U-01A-21D-A19H-09
# 1                SA60348  TCGA-BH-A18U-01A-21D-A19H-09
# 2                SA60324  TCGA-BH-A18U-01A-21D-A12B-09
# 3                SA60324  TCGA-BH-A18U-01A-21D-A12B-09
#
#     submitted_matched_sample_id chromosome  chromosome_start  ...  \
# 0  TCGA-BH-A18U-11A-23D-A19H-09          5          58021869  ...
# 1  TCGA-BH-A18U-11A-23D-A19H-09          5          58021869  ...
# 2  TCGA-BH-A18U-11A-23D-A12B-09          5          58021869  ...
# 3  TCGA-BH-A18U-11A-23D-A12B-09          5          58021869  ...
#
#    experimental_protocol  sequencing_strategy base_calling_algorithm  \
# 0                    NaN                  WGS                    NaN
# 1                    NaN                  WGS                    NaN
# 2                    NaN                  WXS                    NaN
# 3                    NaN                  WXS                    NaN
#
#   alignment_algorithm                        variation_calling_algorithm  \
# 0                 NaN                     PCAWG Consensus SNV-MNV caller
# 1                 NaN                     PCAWG Consensus SNV-MNV caller
# 2                 NaN  TCGA-MC3 https://gdc.cancer.gov/about-data/pub...
# 3                 NaN  TCGA-MC3 https://gdc.cancer.gov/about-data/pub...
#
#   other_analysis_algorithm seq_coverage  raw_data_repository  \
# 0                      NaN          NaN                  NaN
# 1                      NaN          NaN                  NaN
# 2                      NaN          NaN                  GDC
# 3                      NaN          NaN                  GDC
#
#              raw_data_accession  initial_data_release_date
# 0               FI30202:FI30201                        NaN
# 1               FI30202:FI30201                        NaN
# 2  TCGA-BH-A18U-01A-21D-A12B-09                        NaN
# 3  TCGA-BH-A18U-01A-21D-A12B-09                        NaN
#
# [4 rows x 42 columns]

# %%
# Mutation ID MU23549
df[df['icgc_mutation_id'] == 'MU23549']
# Out:
#   icgc_mutation_id icgc_donor_id project_code icgc_specimen_id icgc_sample_id  \
# 4          MU23549        DO5200      BRCA-US          SP10944        SA60228
# 5          MU23549        DO5200      BRCA-US          SP10944        SA60228
# 6          MU23549        DO5200      BRCA-US          SP10944        SA60228
# 7          MU23549        DO5200      BRCA-US          SP10944        SA60252
# 8          MU23549        DO5200      BRCA-US          SP10944        SA60252
# 9          MU23549        DO5200      BRCA-US          SP10944        SA60252
#
#   matched_icgc_sample_id           submitted_sample_id  \
# 4                SA60324  TCGA-BH-A18U-01A-21D-A12B-09
# 5                SA60324  TCGA-BH-A18U-01A-21D-A12B-09
# 6                SA60324  TCGA-BH-A18U-01A-21D-A12B-09
# 7                SA60348  TCGA-BH-A18U-01A-21D-A19H-09
# 8                SA60348  TCGA-BH-A18U-01A-21D-A19H-09
# 9                SA60348  TCGA-BH-A18U-01A-21D-A19H-09
#
#     submitted_matched_sample_id chromosome  chromosome_start  ...  \
# 4  TCGA-BH-A18U-11A-23D-A12B-09          7          70886058  ...
# 5  TCGA-BH-A18U-11A-23D-A12B-09          7          70886058  ...
# 6  TCGA-BH-A18U-11A-23D-A12B-09          7          70886058  ...
# 7  TCGA-BH-A18U-11A-23D-A19H-09          7          70886058  ...
# 8  TCGA-BH-A18U-11A-23D-A19H-09          7          70886058  ...
# 9  TCGA-BH-A18U-11A-23D-A19H-09          7          70886058  ...
#
#    experimental_protocol  sequencing_strategy base_calling_algorithm  \
# 4                    NaN                  WXS                    NaN
# 5                    NaN                  WXS                    NaN
# 6                    NaN                  WXS                    NaN
# 7                    NaN                  WGS                    NaN
# 8                    NaN                  WGS                    NaN
# 9                    NaN                  WGS                    NaN
#
#   alignment_algorithm                        variation_calling_algorithm  \
# 4                 NaN  TCGA-MC3 https://gdc.cancer.gov/about-data/pub...
# 5                 NaN  TCGA-MC3 https://gdc.cancer.gov/about-data/pub...
# 6                 NaN  TCGA-MC3 https://gdc.cancer.gov/about-data/pub...
# 7                 NaN                     PCAWG Consensus SNV-MNV caller
# 8                 NaN                     PCAWG Consensus SNV-MNV caller
# 9                 NaN                     PCAWG Consensus SNV-MNV caller
#
#   other_analysis_algorithm seq_coverage  raw_data_repository  \
# 4                      NaN          NaN                  GDC
# 5                      NaN          NaN                  GDC
# 6                      NaN          NaN                  GDC
# 7                      NaN          NaN                  NaN
# 8                      NaN          NaN                  NaN
# 9                      NaN          NaN                  NaN
#
#              raw_data_accession  initial_data_release_date
# 4  TCGA-BH-A18U-01A-21D-A12B-09                        NaN
# 5  TCGA-BH-A18U-01A-21D-A12B-09                        NaN
# 6  TCGA-BH-A18U-01A-21D-A12B-09                        NaN
# 7               FI30202:FI30201                        NaN
# 8               FI30202:FI30201                        NaN
# 9               FI30202:FI30201                        NaN
#
# [6 rows x 42 columns]

# %% [markdown]
# For the files I looked at (which was only a few so far) there are 42 features.

# %% [markdown]
# # Some EDA

# %%
df.columns
# Out:
# Index(['icgc_mutation_id', 'icgc_donor_id', 'project_code', 'icgc_specimen_id',
#        'icgc_sample_id', 'matched_icgc_sample_id', 'submitted_sample_id',
#        'submitted_matched_sample_id', 'chromosome', 'chromosome_start',
#        'chromosome_end', 'chromosome_strand', 'assembly_version',
#        'mutation_type', 'reference_genome_allele', 'mutated_from_allele',
#        'mutated_to_allele', 'quality_score', 'probability', 'total_read_count',
#        'mutant_allele_read_count', 'verification_status',
#        'verification_platform', 'biological_validation_status',
#        'biological_validation_platform', 'consequence_type', 'aa_mutation',
#        'cds_mutation', 'gene_affected', 'transcript_affected',
#        'gene_build_version', 'platform', 'experimental_protocol',
#        'sequencing_strategy', 'base_calling_algorithm', 'alignment_algorithm',
#        'variation_calling_algorithm', 'other_analysis_algorithm',
#        'seq_coverage', 'raw_data_repository', 'raw_data_accession',
#        'initial_data_release_date'],
#       dtype='object')

# %% [markdown]
# # Choices of features
# - Chromosome start and end may not be helpful though there could exist a relationship between which chromosome and the position of mutation.
# - Do not know what CDS mutation or AA mutation is. Many NaNs here.
# - Do not know how the gene_effected feature is encoded.
# - Project_code can be the target output.
# - Possibly remove start and end features with length of mutation. If a deletion then we can represent with negative number.

# %%
# Choice of features here is due to quick look at the columns. Change as you see fit.
features = ['icgc_mutation_id', 
            'icgc_donor_id', 
            'chromosome', 
            'chromosome_start',
            'chromosome_end',
            'chromosome_strand',
            'reference_genome_allele',
            'mutated_from_allele',
            'mutated_to_allele',
            'consequence_type',
            #'aa_mutation',
            #'cds_mutation',
            'gene_affected',
            #'quality_score',
            #'probability',
            'total_read_count',
            #'seq_coverage', 
            'project_code']
df[features]
# Out:
#      icgc_mutation_id icgc_donor_id chromosome  chromosome_start  \
# 0             MU22195        DO5200          5          58021869
# 1             MU22195        DO5200          5          58021869
# 2             MU22195        DO5200          5          58021869
# 3             MU22195        DO5200          5          58021869
# 4             MU23549        DO5200          7          70886058
# ...               ...           ...        ...               ...
# 2192          MU79396        DO5200          3          48665399
# 2193          MU79396        DO5200          3          48665399
# 2194          MU79396        DO5200          3          48665399
# 2195          MU79396        DO5200          3          48665399
# 2196          MU79396        DO5200          3          48665399
#
#       chromosome_end  chromosome_strand reference_genome_allele  \
# 0           58021869                  1                       C
# 1           58021869                  1                       C
# 2           58021869                  1                       C
# 3           58021869                  1                       C
# 4           70886058                  1                       G
# ...              ...                ...                     ...
# 2192        48665399                  1                       C
# 2193        48665399                  1                       C
# 2194        48665399                  1                       C
# 2195        48665399                  1                       C
# 2196        48665399                  1                       C
#
#      mutated_from_allele mutated_to_allele         consequence_type  \
# 0                      C                 A             exon_variant
# 1                      C                 A         missense_variant
# 2                      C                 A             exon_variant
# 3                      C                 A         missense_variant
# 4                      G                 A              stop_gained
# ...                  ...               ...                      ...
# 2192                   C                 T  downstream_gene_variant
# 2193                   C                 T  downstream_gene_variant
# 2194                   C                 T  downstream_gene_variant
# 2195                   C                 T  downstream_gene_variant
# 2196                   C                 T  downstream_gene_variant
#
#         gene_affected  total_read_count project_code
# 0     ENSG00000152932                68      BRCA-US
# 1     ENSG00000152932                68      BRCA-US
# 2     ENSG00000152932               349      BRCA-US
# 3     ENSG00000152932               349      BRCA-US
# 4     ENSG00000185274                53      BRCA-US
# ...               ...               ...          ...
# 2192  ENSG00000225697               292      BRCA-US
# 2193  ENSG00000225697               292      BRCA-US
# 2194  ENSG00000225697               292      BRCA-US
# 2195  ENSG00000225697               292      BRCA-US
# 2196  ENSG00000225697               292      BRCA-US
#
# [2197 rows x 13 columns]

# %% [markdown]
# # Mutation IDs
# - There are many duplicates. There are only 213 unique mutation IDs for this donor.

# %%
print('There are {} unique mutation IDs'.format(len(set(df[features]['icgc_mutation_id']))))
# Out:
# There are 213 unique mutation IDs

# %%
print('There is only {} donor in this file'.format(len(set(df[features]['icgc_donor_id']))))
# Out:
# There is only 1 donor in this file

# %%
data = df[features]

# %%
data.head()
# Out:
#   icgc_mutation_id icgc_donor_id project_code icgc_specimen_id  \
# 0          MU22195        DO5200      BRCA-US          SP10944
# 1          MU22195        DO5200      BRCA-US          SP10944
# 2          MU22195        DO5200      BRCA-US          SP10944
# 3          MU22195        DO5200      BRCA-US          SP10944
# 4          MU23549        DO5200      BRCA-US          SP10944
#
#   matched_icgc_sample_id chromosome  chromosome_start  chromosome_end  \
# 0                SA60348          5          58021869        58021869
# 1                SA60348          5          58021869        58021869
# 2                SA60324          5          58021869        58021869
# 3                SA60324          5          58021869        58021869
# 4                SA60324          7          70886058        70886058
#
#    chromosome_strand assembly_version  ... probability total_read_count  \
# 0                  1           GRCh37  ...         NaN               68
# 1                  1           GRCh37  ...         NaN               68
# 2                  1           GRCh37  ...         NaN              349
# 3                  1           GRCh37  ...         NaN              349
# 4                  1           GRCh37  ...         NaN               53
#
#   mutant_allele_read_count verification_status  consequence_type  aa_mutation  \
# 0                       12          not tested      exon_variant          NaN
# 1                       12          not tested  missense_variant         A98D
# 2                       49          not tested      exon_variant          NaN
# 3                       49          not tested  missense_variant         A98D
# 4                       37          not tested       stop_gained        W310*
#
#    cds_mutation    gene_affected transcript_affected gene_build_version
# 0           NaN  ENSG00000152932     ENST00000507977                 75
# 1        293C>A  ENSG00000152932     ENST00000282878                 75
# 2           NaN  ENSG00000152932     ENST00000507977                 75
# 3        293C>A  ENSG00000152932     ENST00000282878                 75
# 4        929G>A  ENSG00000185274     ENST00000333538                 75
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Not all mutations are 1bp
# Some mutations involve longer sequences!

# %%
df[df['mutation_type'] == 'deletion of <=200bp'][['mutation_type', 'reference_genome_allele', 'mutated_from_allele', 'mutated_to_allele']].head(5)
# Out:
#            mutation_type reference_genome_allele  mutated_from_allele  \
# 159  deletion of <=200bp     TGCGGAGATTCTCTTCCTC  TGCGGAGATTCTCTTCCTC
# 160  deletion of <=200bp     TGCGGAGATTCTCTTCCTC  TGCGGAGATTCTCTTCCTC
# 161  deletion of <=200bp     TGCGGAGATTCTCTTCCTC  TGCGGAGATTCTCTTCCTC
# 162  deletion of <=200bp     TGCGGAGATTCTCTTCCTC  TGCGGAGATTCTCTTCCTC
# 163  deletion of <=200bp     TGCGGAGATTCTCTTCCTC  TGCGGAGATTCTCTTCCTC
#
#     mutated_to_allele
# 159                 -
# 160                 -
# 161                 -
# 162                 -
# 163                 -

# %%
set(df['consequence_type'])
# Out:
# {'3_prime_UTR_variant',
#  '5_prime_UTR_premature_start_codon_gain_variant',
#  '5_prime_UTR_variant',
#  'disruptive_inframe_deletion',
#  'downstream_gene_variant',
#  'exon_variant',
#  'frameshift_variant',
#  'inframe_deletion',
#  'intron_variant',
#  'missense_variant',
#  'splice_acceptor_variant',
#  'splice_donor_variant',
#  'splice_region_variant',
#  'stop_gained',
#  'synonymous_variant',
#  'upstream_gene_variant'}
